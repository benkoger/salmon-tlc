# %%
import os
import pickle

from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
tracks_folder = os.environ.get("TRACKS_ROOT")

# %%
clip_name = "2025-08-07-tracks-class-3"
tracks_file = os.path.join(tracks_folder, f"{clip_name}.pkl")
tracks = pickle.load(open(tracks_file, 'rb'))

# %%
tracks.keys()
# Out:
# dict_keys([581, 582, 583, 584, 585, 587, 588, 590, 594, 597, 599, 601, 603, 607, 608, 609, 611, 615, 618, 619, 621, 622, 624, 625, 626, 627, 629, 631, 637, 639])

# %%
x_min, y_min, width, height = tracks[584][91]
x = x_min + width / 2
y = y_min + height / 2
print(f"Track 584 at frame 91 has center coordinates: ({x}, {y})")
# Out:
# Track 584 at frame 91 has center coordinates: (1512.2601815299524, 893.5945073576381)
