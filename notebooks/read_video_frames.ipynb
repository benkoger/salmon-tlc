# %%
import matplotlib.pyplot as plt

from imutils.video import FileVideoStream

# %%
video_file = "/mnt/f/pedrobay_2025/mounted-cameras/cam09-trail_outflow/Mp4Record/2025-08-07/RecM0A_DST20250807_225623_225823_0_531E8300000000_1F0BF95.mp4"
fvs = FileVideoStream(video_file).start()

frame_count = 0
while fvs.more():
    frame = fvs.read()
    if frame is None:
        break
    
    # if frame_count % 30 == 0:  # Display every 30th frame
    #     plt.imshow(frame[..., ::-1])  # Convert BGR to RGB
    #     plt.show()
    # if frame_count >= 300:  # Limit to first 300 frames for testing
    #     break
    frame_count += 1

fvs.stop()
