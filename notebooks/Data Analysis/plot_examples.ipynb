# %%
from time_plot_functions import (
    closest_all_fish_distances,
    fish_group_distr_hist,
    gaussian_distr_check,
    interfish_time_dist_plot,
    make_lollipop_plots,
    empirical_totals_plot
)
from gaussian_sampling import group_size_box_plot_gaussian, interfish_emp_gauss
from modeling_plot_functions import get_data_and_fig, plots_d_e, make_full_figure_new

# %%
# this plot gives the closest distances and all distances from one fish to another
closest_all_fish_distances(True, False, False)

# %%
# this plot gives distances from one fish to its next chronological neighbor
interfish_time_dist_plot(True, False, False, False)

# %%
# this plot gives the probability distribution for individual fish for the group sizes
fish_group_distr_hist(10, True, False)

# %%
# this plot is the lollipop plot where the y axis gives the group size and the x axis gives the time of day
make_lollipop_plots(10, False, False)

# %%
# this plot is the lollipop plot with all six cameras and the downstream data as well
cam_names = {
    "cam01-bear_outflow": False,
    "cam07-grass_outflow": False,
    "cam05-airport_outflow": False,
    "cam09-trail_outflow": False,
    "cam0610-big_outflow": True,
    "cam1006-left_arm_big_confluence": True,
}
make_lollipop_plots(10, True, False, cam_names=cam_names)

# %%
# this gives the plot showing how the average of the centered empirical data lines up with the Gaussian cumulative probability distribution
gaussian_distr_check(False)
# Out:
# 18.59273216506489

# %%
# This function gives the fraction of fish crossing for each camera at each time step for the two big days, the 7th and the 10th
empirical_totals_plot(120, False)

# %%
# this function gives a plot with the group size data in boxplots for each run size
group_size_box_plot_gaussian(10, True, False)

# %%
# this function gives the empirical interfish distances compared to the interfish distances from a Gaussian draw
interfish_emp_gauss(True, True, False)

# %%
# This function gives the figure with 6 subplots, like in the 2017 study
get_data_and_fig(120, 0.06, 0.1, False)

# %%
# This function specifically gives the fourth and fifth plots with many iterations and the range for 95% of the values
plots_d_e(120, 0.06, 0.1, 1000, False)

# %%
# this function combines the two outputs above to return a more accurate version of the figure
make_full_figure_new(120, 0.06, 0.1, False)
